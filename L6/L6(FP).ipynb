# %% [markdown]
# # Лабораторна робота №6

# %% [markdown]
# # Варіант 1

# %% [markdown]
# ## Завдання №1
# Завантажте набір даних books.csv.
# ### Код завдання:

# %%
import pandas as pd
import re

books = pd.read_csv('books.csv')
books
# Out:
#                             Title              Author       Genre  \
# 0        Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                      Data Smart       Foreman, John        tech
# 2        God Created the Integers    Hawking, Stephen        tech
# 3               Superfreakonomics     Dubner, Stephen     science
# 4                     Orientalism        Said, Edward  nonfiction
# ..                            ...                 ...         ...
# 206      Structure and Randomness        Tao, Terence     science
# 207  Image Processing with MATLAB       Eddins, Steve        tech
# 208                   Animal Farm      Orwell, George     fiction
# 209                    Idiot, The  Dostoevsky, Fyodor     fiction
# 210            Christmas Carol, A    Dickens, Charles     fiction
#
#               SubGenre  Height      Publisher
# 0    signal_processing     228          Wiley
# 1         data_science     235          Wiley
# ...

# %% [markdown]
# ## Завдання №2
# Створіть новий стовпець "WordsInTitle" із кількістю слів у заголовку.
# ### Код завдання:

# %%
def words_in_title(string):
    return (len(string.split()))
task_2 = books.copy()
task_2['WordsInTitle'] = task_2.apply(lambda x: words_in_title(x.Title), axis=1)
task_2
# Out:
#                             Title              Author       Genre  \
# 0        Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                      Data Smart       Foreman, John        tech
# 2        God Created the Integers    Hawking, Stephen        tech
# 3               Superfreakonomics     Dubner, Stephen     science
# 4                     Orientalism        Said, Edward  nonfiction
# ..                            ...                 ...         ...
# 206      Structure and Randomness        Tao, Terence     science
# 207  Image Processing with MATLAB       Eddins, Steve        tech
# 208                   Animal Farm      Orwell, George     fiction
# 209                    Idiot, The  Dostoevsky, Fyodor     fiction
# 210            Christmas Carol, A    Dickens, Charles     fiction
#
#               SubGenre  Height      Publisher  WordsInTitle
# 0    signal_processing     228          Wiley             3
# ...

# %% [markdown]
# ## Завдання №3
# Знайдіть автора в імені або прізвищі якого э 3 приголосні поспіль.
# ### Код завдання:

# %%
books.loc[books['Author'].str.extract('.*([qwrtpsdfghjklzxcvbnm]{3})').dropna().index.values, 'Title':'Publisher']
# Out:
#                                                  Title  \
# 13     Structure & Interpretation of Computer Programs
# 18                                New Machiavelli, The
# 26                       Beautiful and the Damned, The
# 28               Complete Sherlock Holmes, The - Vol I
# 29              Complete Sherlock Holmes, The - Vol II
# 35                                 Farewell to Arms, A
# 37                                   False Impressions
# 38                                   Last Lecture, The
# 40                                       Jurassic Park
# 46                                         Asami Asami
# 56                         Textbook of Economic Theory
# 58                                     Learning OpenCV
# 59                       Data Structures Using C & C++
# 62                                            Let Us C
# 64                                Crime and Punishment
# 69                                Raisin in the Sun, A
# ...

# %% [markdown]
# ## Завдання №4
# Знайдіть прізвище автора книги з найдовшою назвою.
# ### Код завдання:

# %%
task_5 = books.copy()
task_5['TitleLength'] = task_5['Title'].str.len()
task_5[['Author', 'Title', 'TitleLength']].sort_values(by=['TitleLength'], ascending=False).head(1)
# Out:
#                  Author                                              Title  \
# 115  Huntington, Samuel  Clash of Civilizations and Remaking of the Wor...
#
#      TitleLength
# 115           54

# %% [markdown]
# ## Завдання №5
# Знайдіть книги, у яких першою літерою другого слова в назві є "С".
# ### Код завдання:

# %%
books.loc[books['Title'].str.extract('^\w+ ([C])|$').dropna().index.values, 'Title':'Publisher']
# Out:
#                                      Title            Author       Genre  \
# 2                 God Created the Integers  Hawking, Stephen        tech
# 44                 Hidden Connections, The    Capra, Fritjof     science
# 55    Soft Computing & Intelligent Systems      Gupta, Madan        tech
# 75   Social Choice & Welfare, Vol 39 No. 1           Various        tech
# 134                 Pattern Classification        Duda, Hart        tech
# 138                           Final Crisis               NaN     fiction
# 167                    Jim Corbett Omnibus      Corbett, Jim  nonfiction
# 169                        Batatyachi Chal     Deshpande P L     fiction
# 175                       Think Complexity     Downey, Allen        tech
# 210                     Christmas Carol, A  Dickens, Charles     fiction
#
#          SubGenre  Height      Publisher
# 2     mathematics     197        Penguin
# 44        physics     197  HarperCollins
# ...

# %% [markdown]
# ## Завдання №6
# Знайдіть книги, де в назві є слово, що складається із однієї букви.
# ### Код завдання:

# %%
books.loc[books['Title'].str.extract('([\s]){1}([\w]){1}([\s]){1}').dropna().index.values, 'Title':'Publisher']
# Out:
#                                   Title              Author       Genre  \
# 12                   Birth of a Theorem     Villani, Cedric     science
# 47                   Journal of a Novel     Steinbeck, John     fiction
# 48                 Once There Was a War     Steinbeck, John  nonfiction
# 51                      In a Free State      Naipaul, V. S.     fiction
# 59        Data Structures Using C & C++   Tanenbaum, Andrew        tech
# 60   Computer Vision, A Modern Approach      Forsyth, David        tech
# 120                         Half A Life        Naipaul, V S     fiction
# 131            Trembling of a Leaf, The  Maugham, William S     fiction
#
#               SubGenre  Height      Publisher
# 12         mathematics     234    Bodley Head
# 47             classic     196        Penguin
# 48             history     196        Penguin
# 51               novel     196           Rupa
# 59    computer_science     235  Prentice Hall
# ...

# %% [markdown]
# ## Завдання №7
# Створіть новий DataFrame з усіма книгами, де в назві є цифри.
# ### Код завдання:

# %%
task_7 = books.loc[books['Title'].str.extract('([.*\d+.*])').dropna().index.values, 'Title':'Publisher']
task_7
# Out:
#                                         Title              Author    Genre  \
# 52                                   Catch 22      Heller, Joseph  fiction
# 59              Data Structures Using C & C++   Tanenbaum, Andrew     tech
# 75      Social Choice & Welfare, Vol 39 No. 1             Various     tech
# 105  Maugham's Collected Short Stories, Vol 3  Maugham, William S  fiction
# 143               Numbers Behind Numb3rs, The       Devlin, Keith  science
# 144                    Superman Earth One - 1                 NaN  fiction
# 145                    Superman Earth One - 2                 NaN  fiction
# 153        Journal of Economics, vol 106 No 3                 NaN  science
# 168               20000 Leagues Under the Sea        Verne, Jules  fiction
#
#              SubGenre  Height      Publisher
# 52            classic     178   Random House
# 59   computer_science     235  Prentice Hall
# 75          economics     235       Springer
# ...

# %% [markdown]
# ## Завдання №8
# В датафреймі, створеному в попередньому завданні створіть новий
# стовпець, з числами, що є в назві. Якщо в назві декілька цифр,
# об’єднайте їх за допомогою „+“ (наприклад, „39 +1“).
# ### Код завдання:

# %%
task_8 = task_7
def numbers_in_title(string):
    string = "".join(re.findall('[.*[\d]+]*', str(string).lower())) 
######################
task_8['NumbersInTitle'] = task_8.apply(lambda x: numbers_in_title(x.Title), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-253-94dd09f65f0f> in <module>
#       3     string = "".join(re.findall('[.*[\d]+]*', str(string).lower()))
#       4 ######################
# ----> 5 task_8['NumbersInTitle'] = task_8.apply(lambda x: numbers_in_title(x.Title), axis=1)
#
# E:\Apps\Anaconda\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7763             kwds=kwds,
#    7764         )
# -> 7765         return op.get_result()
#    7766
#    7767     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# E:\Apps\Anaconda\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# ...
